# %%
import pandas as pd

# %%
xls = pd.ExcelFile("/Users/joseph/Downloads/Physics Electric Potential Assignment.xlsx")
## mini function but I'm too lazy to write it as one
df1 = pd.read_excel(xls, "Extension", header=None)

# %%
df1
# Out:
#            0          1          2          3          4          5   \
# 0   16.298214  16.510440  16.715467  16.912553  17.101082  17.280597
# 1   16.775566  17.003987  17.224408  17.435901  17.637674  17.829117
# 2   17.280901  17.527480  17.765151  17.992749  18.209252  18.413842
# 3   17.816930  18.084010  18.341168  18.586939  18.820000  19.039249
# 4   18.386689  18.677086  18.956450  19.222930  19.474817  19.710632
# 5   18.993569  19.310685  19.615573  19.905900  20.179457  20.434271
# 6   19.641345  19.989303  20.323789  20.641866  20.940684  21.217625
# 7   20.334191  20.718008  21.087114  21.437820  21.766464  22.069583
# 8   21.076692  21.502483  21.912424  22.301888  22.666182  23.000751
# 9   21.873831  22.349069  22.807555  23.243504  23.650917  24.023826
# 10  22.730942  23.264774  23.781398  24.273610  24.733757  25.154040
# 11  23.653627  24.257252  24.843980  25.404870  25.930182  26.409743
# 12  24.647589  25.334722  26.006505  26.651897  27.258527  27.813129
# ...

# %%
values = df1.to_numpy().flatten()

# %%
values
# Out:
# array([16.29821357, 16.51043981, 16.71546702, ..., 14.53938585,
#        13.91165358, 13.39472603])

# %%
pasteboard = ""
for i in values:
    pasteboard += str(i) + "\n"

# %%
import subprocess 
subprocess.run("pbcopy", text=True, input=pasteboard)
# Out:
# CompletedProcess(args='pbcopy', returncode=0)
